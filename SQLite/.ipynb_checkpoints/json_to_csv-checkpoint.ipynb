# %%
import json
import csv
import pandas
import sqlite3

# %%
ls
# Out:
# BAKC.csv              json_to_csv.ipynb     meebit.json
# Collection JSONs/     json_to_sqlite.ipynb  nft_database.db
# azuki.csv             meebit.csv

# %%
with open('Collection JSONs/BAKC.json') as json_file:
    jsondata = json.load(json_file)

# %%
data_file = open('BAKC.csv', 'w+', newline='')
csv_writer = csv.writer(data_file)

# %%
count = 0
for data in jsondata:
    if type(data["value"]) != type(1):
        print(type(data["value"]))
    if count == 0:
        header = data.keys()
        csv_writer.writerow(header)
        count += 1
    csv_writer.writerow(data.values())
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
conn = sqlite3.connect('nft_database.db')
c = conn.cursor()

# %%
dtypes = {
    'block_number': 'int', 
    'block_timestamp': 'str', 
    'block_hash': 'str', 
    'transaction_hash': 'str',
    'transaction_index': 'str',
    'log_index': 'str',
    'value': 'str',
    'contract_type': 'str',
    'transaction_type': 'str',
    'token_address': 'str',
    'token_id': 'str',
    'from_address': 'str',
    'to_address': 'str',
    'amount': 'str',
    'verified': 'str',
    'operator': 'str'
}

df = pandas.read_csv("BAKC.csv", dtype=dtypes)
# df.to_sql("BAKC", conn, if_exists='append', index=False)
# Out:
# /var/folders/6j/k90prlsd4m51gdfbh7ht81900000gn/T/ipykernel_8624/1666621492.py:16: DtypeWarning: Columns (0,4,5,6,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pandas.read_csv("BAKC.csv")

# %%
data_file.close()
